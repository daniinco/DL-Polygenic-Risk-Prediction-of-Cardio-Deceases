# %%
import os
import pandas as pd
import subprocess
import numpy as np
from sklearn.preprocessing import StandardScaler
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
from sklearn.metrics import roc_auc_score
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.feature_selection import SelectKBest, f_classif, mutual_info_classif
from sklearn.preprocessing import StandardScaler

# %%
import warnings

warnings.filterwarnings("ignore", category=FutureWarning)

# %%
os.makedirs('./parts', exist_ok=True)

# %%
subprocess.run(['plink', '--bfile', './filtered_data', '--write-snplist', '--out', './temp_snplist'], check=True)
# Out:
# PLINK v1.9.0-b.7.7 64-bit (22 Oct 2024)            cog-genomics.org/plink/1.9/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to ./temp_snplist.log.
# Options in effect:
#   --bfile ./filtered_data
#   --out ./temp_snplist
#   --write-snplist
#
# 16384 MB RAM detected; reserving 8192 MB for main workspace.
# 591998 variants loaded from .bim file.
# 1401 people (937 males, 464 females) loaded from .fam.
# 1401 phenotype values loaded from .fam.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 1401 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.991679.
# 591998 variants and 1401 people pass filters and QC.
# Among remaining phenotypes, 933 are cases and 468 are controls.
# List of variant IDs written to ./temp_snplist.snplist .
# CompletedProcess(args=['plink', '--bfile', './filtered_data', '--write-snplist', '--out', './temp_snplist'], returncode=0)

# %%
from sklearn.preprocessing import OneHotEncoder

def create_genome(x, a1, a2):
    if x == 0.0:
        return f"{a1}{a1}"
    elif x == 1.0:
        return f"{a1}{a2}"
    elif x == 2.0:
        return f"{a2}{a2}"
    else:
        return f"-"

# %%
from tqdm import tqdm

def get_raw_data_parts(part_path, input_plink):
    dfs = []
    with open('./temp_snplist.snplist', 'r') as f:
        all_snps = [line.strip() for line in f]
    total_snps = len(all_snps)
    chunk_size = total_snps // 1000
    if total_snps % 1000 > 0:
        chunk_size += 1  # округляем вверх

    for i in tqdm(range(1000)):
        start_idx = i * chunk_size
        end_idx = min((i + 1) * chunk_size, total_snps)
        
        if start_idx >= total_snps:
            break
        
        part_snps = all_snps[start_idx:end_idx]
        part_name = f"{part_path}/part_{i:03d}"
        
        snp_file = f"{part_name}.snplist"
        with open(snp_file, 'w') as f:
            for snp in part_snps:
                f.write(f"{snp}\n")
        
        subprocess.run([
            'plink',
            '--bfile', input_plink,
            '--extract', snp_file,
            '--make-bed',
            '--out', part_name
        ], check=True, 
        stdout=subprocess.DEVNULL, 
        stderr=subprocess.DEVNULL)
        
        subprocess.run([
            'plink',
            '--bfile', part_name,
            '--recodeA',
            '--out', part_name
        ], check=True, 
        stdout=subprocess.DEVNULL, 
        stderr=subprocess.DEVNULL)
        
        raw_file = f"{part_name}.raw"
        df = pd.read_csv(raw_file, delim_whitespace=True)
        dfs.append(df)

    return dfs

# %%
raw_train = get_raw_data_parts("./parts", "all_train")
raw_test = get_raw_data_parts("./parts", "validation")
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]Python(66754) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(66755) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   0%|          | 1/1000 [00:00<12:28,  1.33it/s]Python(66756) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(66757) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   0%|          | 2/1000 [00:01<12:24,  1.34it/s]Python(66758) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(66759) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   0%|          | 3/1000 [00:02<11:37,  1.43it/s]Python(66760) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(66761) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   0%|          | 4/1000 [00:02<10:31,  1.58it/s]Python(66762) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(66763) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   0%|          | 5/1000 [00:03<09:44,  1.70it/s]Python(66764) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(66765) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   1%|          | 6/1000 [00:03<09:08,  1.81it/s]Python(66766) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(66767) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   1%|          | 7/1000 [00:04<08:39,  1.91it/s]Python(66768) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(66769) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   1%|          | 8/1000 [00:04<08:21,  1.98it/s]Python(66770) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(66771) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   1%|          | 9/1000 [00:05<08:06,  2.04it/s]Python(66772) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(66773) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   1%|          | 10/1000 [00:05<08:02,  2.05it/s]Python(66774) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(66775) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   1%|          | 11/1000 [00:06<08:01,  2.06it/s]Python(66776) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(66777) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   1%|          | 12/1000 [00:06<08:00,  2.06it/s]Python(66778) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(66779) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   1%|▏         | 13/1000 [00:06<08:01,  2.05it/s]Python(66780) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(66781) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   1%|▏         | 14/1000 [00:07<07:59,  2.06it/s]Python(66783) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(66784) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   2%|▏         | 15/1000 [00:07<07:57,  2.06it/s]Python(66785) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(66786) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   2%|▏         | 16/1000 [00:08<07:57,  2.06it/s]Python(66787) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(66788) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   2%|▏         | 17/1000 [00:08<07:52,  2.08it/s]Python(66789) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(66791) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   2%|▏         | 18/1000 [00:09<07:52,  2.08it/s]Python(66792) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(66793) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   2%|▏         | 19/1000 [00:09<07:51,  2.08it/s]Python(66794) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(66795) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   2%|▏         | 20/1000 [00:10<07:47,  2.10it/s]Python(66796) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(66797) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   2%|▏         | 21/1000 [00:10<08:35,  1.90it/s]Python(66798) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(66799) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   2%|▏         | 22/1000 [00:11<09:26,  1.73it/s]Python(66800) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(66801) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   2%|▏         | 23/1000 [00:12<10:27,  1.56it/s]Python(66802) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(66803) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   2%|▏         | 24/1000 [00:13<11:25,  1.42it/s]Python(66804) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(66805) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   2%|▎         | 25/1000 [00:14<11:29,  1.41it/s]Python(66806) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(66807) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   3%|▎         | 26/1000 [00:14<10:51,  1.49it/s]Python(66808) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(66809) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   3%|▎         | 27/1000 [00:15<10:57,  1.48it/s]Python(66811) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(66813) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   3%|▎         | 28/1000 [00:15<10:06,  1.60it/s]Python(66814) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(66815) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   3%|▎         | 29/1000 [00:16<09:06,  1.78it/s]Python(66816) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(66817) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   3%|▎         | 30/1000 [00:16<08:35,  1.88it/s]Python(66818) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(66819) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   3%|▎         | 31/1000 [00:17<08:15,  1.95it/s]Python(66820) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(66821) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   3%|▎         | 32/1000 [00:17<08:06,  1.99it/s]Python(66822) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(66823) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   3%|▎         | 33/1000 [00:18<07:54,  2.04it/s]Python(66824) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(66825) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   3%|▎         | 34/1000 [00:18<07:47,  2.07it/s]Python(66826) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(66827) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   4%|▎         | 35/1000 [00:19<08:19,  1.93it/s]Python(66829) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(66830) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   4%|▎         | 36/1000 [00:19<08:02,  2.00it/s]Python(66831) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(66832) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   4%|▎         | 37/1000 [00:20<08:10,  1.96it/s]Python(66833) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(66834) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   4%|▍         | 38/1000 [00:20<08:30,  1.88it/s]Python(66835) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(66836) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   4%|▍         | 39/1000 [00:21<08:45,  1.83it/s]Python(66837) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(66838) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   4%|▍         | 40/1000 [00:22<09:27,  1.69it/s]Python(66839) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(66840) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   4%|▍         | 41/1000 [00:22<10:54,  1.47it/s]Python(66841) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(66842) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   4%|▍         | 42/1000 [00:23<10:57,  1.46it/s]Python(66843) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(66844) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   4%|▍         | 43/1000 [00:24<09:58,  1.60it/s]Python(66845) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(66846) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   4%|▍         | 44/1000 [00:24<09:10,  1.74it/s]Python(66847) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(66848) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   4%|▍         | 45/1000 [00:24<08:30,  1.87it/s]Python(66849) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(66850) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   5%|▍         | 46/1000 [00:25<08:03,  1.97it/s]Python(66851) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(66852) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   5%|▍         | 47/1000 [00:25<07:46,  2.04it/s]Python(66853) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(66854) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   5%|▍         | 48/1000 [00:26<07:34,  2.10it/s]Python(66855) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(66856) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   5%|▍         | 49/1000 [00:26<07:33,  2.10it/s]Python(66857) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(66858) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   5%|▌         | 50/1000 [00:27<07:28,  2.12it/s]Python(66859) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(66860) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   5%|▌         | 51/1000 [00:27<07:25,  2.13it/s]Python(66861) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(66862) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   5%|▌         | 52/1000 [00:28<07:25,  2.13it/s]Python(66863) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(66864) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   5%|▌         | 53/1000 [00:28<07:25,  2.13it/s]Python(66865) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(66866) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   5%|▌         | 54/1000 [00:29<07:23,  2.13it/s]Python(66867) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(66869) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   6%|▌         | 55/1000 [00:29<07:27,  2.11it/s]Python(66870) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(66871) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   6%|▌         | 56/1000 [00:30<07:27,  2.11it/s]Python(66872) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(66873) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   6%|▌         | 57/1000 [00:30<07:21,  2.13it/s]Python(66874) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(66875) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   6%|▌         | 58/1000 [00:30<07:15,  2.16it/s]Python(66876) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(66877) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   6%|▌         | 59/1000 [00:31<07:12,  2.18it/s]Python(66878) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(66879) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   6%|▌         | 60/1000 [00:31<07:06,  2.21it/s]Python(66880) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(66881) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   6%|▌         | 61/1000 [00:32<07:03,  2.22it/s]Python(66882) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(66883) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   6%|▌         | 62/1000 [00:32<07:00,  2.23it/s]Python(66884) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(66885) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   6%|▋         | 63/1000 [00:33<07:01,  2.22it/s]Python(66886) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(66887) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   6%|▋         | 64/1000 [00:33<07:02,  2.21it/s]Python(66888) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(66889) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   6%|▋         | 65/1000 [00:34<07:01,  2.22it/s]Python(66890) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(66891) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   7%|▋         | 66/1000 [00:34<07:05,  2.19it/s]Python(66892) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(66893) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   7%|▋         | 67/1000 [00:35<07:11,  2.16it/s]Python(66894) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(66895) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   7%|▋         | 68/1000 [00:35<07:19,  2.12it/s]Python(66896) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(66897) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   7%|▋         | 69/1000 [00:36<07:10,  2.16it/s]Python(66898) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(66899) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   7%|▋         | 70/1000 [00:36<07:07,  2.18it/s]Python(66900) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(66901) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   7%|▋         | 71/1000 [00:36<07:02,  2.20it/s]Python(66902) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(66903) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   7%|▋         | 72/1000 [00:37<07:04,  2.19it/s]Python(66905) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(66906) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   7%|▋         | 73/1000 [00:37<06:58,  2.21it/s]Python(66907) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(66908) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   7%|▋         | 74/1000 [00:38<06:59,  2.21it/s]Python(66909) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(66910) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   8%|▊         | 75/1000 [00:38<06:55,  2.23it/s]Python(66911) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(66912) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   8%|▊         | 76/1000 [00:39<06:54,  2.23it/s]Python(66913) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(66915) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   8%|▊         | 77/1000 [00:39<07:03,  2.18it/s]Python(66916) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(66917) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   8%|▊         | 78/1000 [00:40<07:04,  2.17it/s]Python(66918) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(66919) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   8%|▊         | 79/1000 [00:40<07:01,  2.19it/s]Python(66920) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(66921) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   8%|▊         | 80/1000 [00:41<07:39,  2.00it/s]Python(66922) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(66923) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   8%|▊         | 81/1000 [00:41<07:25,  2.06it/s]Python(66924) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(66925) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   8%|▊         | 82/1000 [00:42<07:23,  2.07it/s]Python(66926) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(66931) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   8%|▊         | 83/1000 [00:42<07:23,  2.07it/s]Python(66937) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(66941) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   8%|▊         | 84/1000 [00:43<07:13,  2.11it/s]Python(66942) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(66943) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   8%|▊         | 85/1000 [00:43<07:08,  2.14it/s]Python(66944) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(66945) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   9%|▊         | 86/1000 [00:43<07:13,  2.11it/s]Python(66946) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(66947) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   9%|▊         | 87/1000 [00:44<07:07,  2.14it/s]Python(66948) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(66949) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   9%|▉         | 88/1000 [00:44<07:04,  2.15it/s]Python(66950) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(66951) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   9%|▉         | 89/1000 [00:45<06:58,  2.18it/s]Python(66952) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(66953) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   9%|▉         | 90/1000 [00:45<06:57,  2.18it/s]Python(66954) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(66955) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   9%|▉         | 91/1000 [00:46<06:59,  2.17it/s]Python(66956) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(66957) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   9%|▉         | 92/1000 [00:46<06:58,  2.17it/s]Python(66958) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(66959) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   9%|▉         | 93/1000 [00:47<06:56,  2.18it/s]Python(66960) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(66961) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   9%|▉         | 94/1000 [00:47<06:59,  2.16it/s]Python(66962) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(66963) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  10%|▉         | 95/1000 [00:48<07:03,  2.14it/s]Python(66964) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(66965) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  10%|▉         | 96/1000 [00:48<06:57,  2.16it/s]Python(66966) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(66967) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  10%|▉         | 97/1000 [00:49<06:55,  2.17it/s]Python(66968) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(66969) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  10%|▉         | 98/1000 [00:49<06:54,  2.18it/s]Python(66971) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(66972) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  10%|▉         | 99/1000 [00:49<06:50,  2.19it/s]Python(66973) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(66974) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  10%|█         | 100/1000 [00:50<06:46,  2.21it/s]Python(66975) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(66976) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  10%|█         | 101/1000 [00:50<06:45,  2.22it/s]Python(66977) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(66978) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  10%|█         | 102/1000 [00:51<06:45,  2.21it/s]Python(66979) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(66980) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  10%|█         | 103/1000 [00:51<06:48,  2.19it/s]Python(66981) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(66982) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  10%|█         | 104/1000 [00:52<06:52,  2.17it/s]Python(66983) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(66984) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  10%|█         | 105/1000 [00:52<06:48,  2.19it/s]Python(66985) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(66986) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  11%|█         | 106/1000 [00:53<06:47,  2.20it/s]Python(66987) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(66988) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  11%|█         | 107/1000 [00:53<06:43,  2.21it/s]Python(66989) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(66990) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  11%|█         | 108/1000 [00:54<06:48,  2.18it/s]Python(66991) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(66992) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  11%|█         | 109/1000 [00:54<06:45,  2.20it/s]Python(66993) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(66994) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  11%|█         | 110/1000 [00:54<06:54,  2.15it/s]Python(66995) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(66996) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  11%|█         | 111/1000 [00:55<06:57,  2.13it/s]Python(66997) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(66998) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  11%|█         | 112/1000 [00:55<06:52,  2.15it/s]Python(66999) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(67000) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  11%|█▏        | 113/1000 [00:56<06:49,  2.17it/s]Python(67001) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(67002) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  11%|█▏        | 114/1000 [00:56<06:55,  2.13it/s]Python(67003) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(67004) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  12%|█▏        | 115/1000 [00:57<06:50,  2.16it/s]Python(67005) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(67006) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  12%|█▏        | 116/1000 [00:57<06:51,  2.15it/s]Python(67007) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(67008) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  12%|█▏        | 117/1000 [00:58<06:52,  2.14it/s]Python(67009) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(67010) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  12%|█▏        | 118/1000 [00:58<06:47,  2.16it/s]Python(67011) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(67012) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  12%|█▏        | 119/1000 [00:59<06:42,  2.19it/s]Python(67013) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(67015) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  12%|█▏        | 120/1000 [00:59<07:30,  1.95it/s]Python(67016) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(67017) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  12%|█▏        | 121/1000 [01:00<07:15,  2.02it/s]Python(67018) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(67019) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  12%|█▏        | 122/1000 [01:00<07:06,  2.06it/s]Python(67020) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(67021) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  12%|█▏        | 123/1000 [01:01<06:59,  2.09it/s]Python(67022) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(67023) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  12%|█▏        | 124/1000 [01:01<06:57,  2.10it/s]Python(67024) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(67025) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  12%|█▎        | 125/1000 [01:02<06:55,  2.11it/s]Python(67026) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(67027) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  13%|█▎        | 126/1000 [01:02<06:48,  2.14it/s]Python(67028) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(67029) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  13%|█▎        | 127/1000 [01:02<06:47,  2.14it/s]Python(67030) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(67031) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  13%|█▎        | 128/1000 [01:03<06:41,  2.17it/s]Python(67032) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(67033) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  13%|█▎        | 129/1000 [01:03<06:41,  2.17it/s]Python(67034) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(67035) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  13%|█▎        | 130/1000 [01:04<06:43,  2.16it/s]Python(67036) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(67037) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  13%|█▎        | 131/1000 [01:04<06:37,  2.19it/s]Python(67038) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(67039) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  13%|█▎        | 132/1000 [01:05<06:39,  2.17it/s]Python(67040) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(67041) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  13%|█▎        | 133/1000 [01:05<06:37,  2.18it/s]Python(67042) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(67043) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  13%|█▎        | 134/1000 [01:06<06:39,  2.17it/s]Python(67044) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(67045) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  14%|█▎        | 135/1000 [01:06<06:39,  2.16it/s]Python(67046) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(67047) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  14%|█▎        | 136/1000 [01:07<06:40,  2.15it/s]Python(67048) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(67049) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  14%|█▎        | 137/1000 [01:07<06:39,  2.16it/s]Python(67050) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(67051) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  14%|█▍        | 138/1000 [01:08<06:37,  2.17it/s]Python(67052) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(67053) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  14%|█▍        | 139/1000 [01:08<06:37,  2.17it/s]Python(67054) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(67055) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  14%|█▍        | 140/1000 [01:08<06:36,  2.17it/s]Python(67056) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(67057) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  14%|█▍        | 141/1000 [01:09<06:34,  2.18it/s]Python(67058) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(67060) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  14%|█▍        | 142/1000 [01:09<06:36,  2.16it/s]Python(67061) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(67062) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  14%|█▍        | 143/1000 [01:10<06:34,  2.17it/s]Python(67063) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(67064) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  14%|█▍        | 144/1000 [01:10<06:32,  2.18it/s]Python(67065) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(67066) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  14%|█▍        | 145/1000 [01:11<06:32,  2.18it/s]Python(67067) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(67068) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  15%|█▍        | 146/1000 [01:11<06:32,  2.18it/s]Python(67069) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(67070) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  15%|█▍        | 147/1000 [01:12<06:30,  2.18it/s]Python(67071) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(67072) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  15%|█▍        | 148/1000 [01:12<06:29,  2.19it/s]Python(67073) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(67074) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  15%|█▍        | 149/1000 [01:13<06:28,  2.19it/s]Python(67075) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(67076) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  15%|█▌        | 150/1000 [01:13<06:24,  2.21it/s]Python(67077) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(67078) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  15%|█▌        | 151/1000 [01:14<06:29,  2.18it/s]Python(67079) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(67080) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  15%|█▌        | 152/1000 [01:14<06:27,  2.19it/s]Python(67081) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(67082) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  15%|█▌        | 153/1000 [01:14<06:29,  2.17it/s]Python(67083) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(67084) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  15%|█▌        | 154/1000 [01:15<06:25,  2.20it/s]Python(67085) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(67086) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  16%|█▌        | 155/1000 [01:15<06:24,  2.20it/s]Python(67087) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(67088) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  16%|█▌        | 156/1000 [01:16<06:22,  2.20it/s]Python(67089) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(67090) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  16%|█▌        | 157/1000 [01:16<06:24,  2.19it/s]Python(67091) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(67092) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  16%|█▌        | 158/1000 [01:17<06:24,  2.19it/s]Python(67093) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(67094) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  16%|█▌        | 159/1000 [01:17<06:23,  2.19it/s]Python(67095) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(67156) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  16%|█▌        | 160/1000 [01:18<06:30,  2.15it/s]Python(67157) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(67160) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  16%|█▌        | 161/1000 [01:18<06:32,  2.14it/s]Python(67170) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(67187) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  16%|█▌        | 162/1000 [01:19<06:37,  2.11it/s]Python(67199) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(67200) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  16%|█▋        | 163/1000 [01:19<06:38,  2.10it/s]Python(67209) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(67217) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  16%|█▋        | 164/1000 [01:20<06:41,  2.08it/s]Python(67223) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(67231) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  16%|█▋        | 165/1000 [01:20<06:57,  2.00it/s]Python(67237) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(67244) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  17%|█▋        | 166/1000 [01:21<06:52,  2.02it/s]Python(67248) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(67253) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  17%|█▋        | 167/1000 [01:21<06:45,  2.05it/s]Python(67255) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(67257) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  17%|█▋        | 168/1000 [01:22<06:37,  2.09it/s]Python(67260) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(67262) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  17%|█▋        | 169/1000 [01:22<06:33,  2.11it/s]Python(67263) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(67264) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  17%|█▋        | 170/1000 [01:22<06:26,  2.15it/s]Python(67265) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(67266) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  17%|█▋        | 171/1000 [01:23<06:20,  2.18it/s]Python(67267) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(67268) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  17%|█▋        | 172/1000 [01:23<06:14,  2.21it/s]Python(67269) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(67270) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  17%|█▋        | 173/1000 [01:24<06:16,  2.20it/s]Python(67271) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(67277) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  17%|█▋        | 174/1000 [01:24<06:15,  2.20it/s]Python(67279) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(67282) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  18%|█▊        | 175/1000 [01:25<06:18,  2.18it/s]Python(67291) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(67294) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  18%|█▊        | 176/1000 [01:25<06:15,  2.20it/s]Python(67295) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(67296) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  18%|█▊        | 177/1000 [01:26<06:15,  2.19it/s]Python(67297) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(67298) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  18%|█▊        | 178/1000 [01:26<06:22,  2.15it/s]Python(67299) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(67300) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  18%|█▊        | 179/1000 [01:27<06:32,  2.09it/s]Python(67301) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(67302) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  18%|█▊        | 180/1000 [01:27<06:33,  2.08it/s]Python(67303) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(67304) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  18%|█▊        | 181/1000 [01:28<06:26,  2.12it/s]Python(67305) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(67306) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  18%|█▊        | 182/1000 [01:28<06:25,  2.12it/s]Python(67307) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(67308) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  18%|█▊        | 183/1000 [01:28<06:20,  2.14it/s]Python(67309) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(67310) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  18%|█▊        | 184/1000 [01:29<06:15,  2.17it/s]Python(67311) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(67312) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  18%|█▊        | 185/1000 [01:29<06:15,  2.17it/s]Python(67313) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(67318) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  19%|█▊        | 186/1000 [01:30<06:17,  2.16it/s]Python(67320) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(67323) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  19%|█▊        | 187/1000 [01:30<06:15,  2.17it/s]Python(67325) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(67328) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  19%|█▉        | 188/1000 [01:31<06:14,  2.17it/s]Python(67329) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(67330) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  19%|█▉        | 189/1000 [01:31<06:12,  2.18it/s]Python(67331) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(67332) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  19%|█▉        | 190/1000 [01:32<06:11,  2.18it/s]Python(67333) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(67334) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  19%|█▉        | 191/1000 [01:32<06:13,  2.17it/s]Python(67335) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(67336) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  19%|█▉        | 192/1000 [01:33<06:12,  2.17it/s]Python(67337) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(67338) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  19%|█▉        | 193/1000 [01:33<06:09,  2.18it/s]Python(67339) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(67340) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  19%|█▉        | 194/1000 [01:34<06:08,  2.19it/s]Python(67341) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(67342) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  20%|█▉        | 195/1000 [01:34<06:05,  2.20it/s]Python(67343) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# ...
# Python(71948) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  94%|█████████▎| 936/1000 [07:36<00:44,  1.44it/s]Python(71949) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(71950) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  94%|█████████▎| 937/1000 [07:37<00:43,  1.45it/s]Python(71951) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(71952) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  94%|█████████▍| 938/1000 [07:38<00:42,  1.46it/s]Python(71953) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(71954) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  94%|█████████▍| 939/1000 [07:38<00:41,  1.47it/s]Python(71955) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(71956) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  94%|█████████▍| 940/1000 [07:39<00:40,  1.49it/s]Python(71957) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(71958) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  94%|█████████▍| 941/1000 [07:40<00:40,  1.46it/s]Python(71959) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(71960) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  94%|█████████▍| 942/1000 [07:41<00:41,  1.40it/s]Python(71961) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(71964) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  94%|█████████▍| 943/1000 [07:41<00:40,  1.41it/s]Python(71965) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(71966) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  94%|█████████▍| 944/1000 [07:42<00:39,  1.44it/s]Python(71967) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(71968) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  94%|█████████▍| 945/1000 [07:43<00:37,  1.45it/s]Python(71969) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(71970) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  95%|█████████▍| 946/1000 [07:43<00:37,  1.43it/s]Python(71971) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(71973) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  95%|█████████▍| 947/1000 [07:44<00:36,  1.44it/s]Python(71975) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(71976) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  95%|█████████▍| 948/1000 [07:45<00:35,  1.46it/s]Python(71977) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(71978) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  95%|█████████▍| 949/1000 [07:45<00:34,  1.47it/s]Python(71979) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(71980) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  95%|█████████▌| 950/1000 [07:46<00:35,  1.40it/s]Python(71981) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(71982) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  95%|█████████▌| 951/1000 [07:47<00:35,  1.40it/s]Python(71983) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(71986) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  95%|█████████▌| 952/1000 [07:48<00:33,  1.42it/s]Python(71996) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(72009) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  95%|█████████▌| 953/1000 [07:48<00:33,  1.42it/s]Python(72019) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(72026) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  95%|█████████▌| 954/1000 [07:49<00:31,  1.45it/s]Python(72027) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(72036) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  96%|█████████▌| 955/1000 [07:50<00:30,  1.48it/s]Python(72038) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(72052) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  96%|█████████▌| 956/1000 [07:50<00:29,  1.47it/s]Python(72055) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(72067) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  96%|█████████▌| 957/1000 [07:51<00:29,  1.45it/s]Python(72074) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(72083) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  96%|█████████▌| 958/1000 [07:52<00:30,  1.40it/s]Python(72085) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(72089) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  96%|█████████▌| 959/1000 [07:52<00:29,  1.41it/s]Python(72092) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(72095) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  96%|█████████▌| 960/1000 [07:53<00:27,  1.44it/s]Python(72096) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(72097) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  96%|█████████▌| 961/1000 [07:54<00:26,  1.49it/s]Python(72099) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(72100) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  96%|█████████▌| 962/1000 [07:54<00:25,  1.51it/s]Python(72101) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(72102) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  96%|█████████▋| 963/1000 [07:55<00:24,  1.54it/s]Python(72103) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(72108) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  96%|█████████▋| 964/1000 [07:56<00:23,  1.53it/s]Python(72110) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(72114) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  96%|█████████▋| 965/1000 [07:56<00:22,  1.54it/s]Python(72115) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(72123) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  97%|█████████▋| 966/1000 [07:57<00:23,  1.46it/s]Python(72125) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(72128) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  97%|█████████▋| 967/1000 [07:58<00:22,  1.48it/s]Python(72129) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(72130) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  97%|█████████▋| 968/1000 [07:58<00:21,  1.50it/s]Python(72131) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(72132) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  97%|█████████▋| 969/1000 [07:59<00:20,  1.51it/s]Python(72133) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(72134) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  97%|█████████▋| 970/1000 [08:00<00:19,  1.51it/s]Python(72135) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(72137) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  97%|█████████▋| 971/1000 [08:00<00:19,  1.49it/s]Python(72138) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(72139) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  97%|█████████▋| 972/1000 [08:01<00:19,  1.47it/s]Python(72140) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(72141) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  97%|█████████▋| 973/1000 [08:02<00:18,  1.45it/s]Python(72143) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(72144) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  97%|█████████▋| 974/1000 [08:03<00:18,  1.38it/s]Python(72145) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(72146) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  98%|█████████▊| 975/1000 [08:03<00:18,  1.38it/s]Python(72148) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(72151) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  98%|█████████▊| 976/1000 [08:04<00:17,  1.36it/s]Python(72152) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(72153) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  98%|█████████▊| 977/1000 [08:05<00:16,  1.40it/s]Python(72154) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(72155) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  98%|█████████▊| 978/1000 [08:05<00:15,  1.43it/s]Python(72156) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(72157) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  98%|█████████▊| 979/1000 [08:06<00:14,  1.44it/s]Python(72161) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(72163) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  98%|█████████▊| 980/1000 [08:07<00:13,  1.45it/s]Python(72167) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(72169) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  98%|█████████▊| 981/1000 [08:07<00:13,  1.45it/s]Python(72170) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(72171) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  98%|█████████▊| 982/1000 [08:08<00:12,  1.40it/s]Python(72172) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(72173) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  98%|█████████▊| 983/1000 [08:09<00:11,  1.44it/s]Python(72175) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(72176) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  98%|█████████▊| 984/1000 [08:10<00:10,  1.48it/s]Python(72177) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(72179) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  98%|█████████▊| 985/1000 [08:10<00:10,  1.48it/s]Python(72180) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(72181) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  99%|█████████▊| 986/1000 [08:11<00:09,  1.49it/s]Python(72182) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(72183) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  99%|█████████▊| 987/1000 [08:12<00:08,  1.49it/s]Python(72184) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(72185) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  99%|█████████▉| 988/1000 [08:12<00:08,  1.49it/s]Python(72186) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(72187) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  99%|█████████▉| 989/1000 [08:13<00:07,  1.48it/s]Python(72188) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(72189) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  99%|█████████▉| 990/1000 [08:14<00:07,  1.39it/s]Python(72190) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(72192) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  99%|█████████▉| 991/1000 [08:14<00:06,  1.39it/s]Python(72193) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(72194) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  99%|█████████▉| 992/1000 [08:15<00:05,  1.41it/s]Python(72195) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(72196) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  99%|█████████▉| 993/1000 [08:16<00:04,  1.43it/s]Python(72197) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(72198) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  99%|█████████▉| 994/1000 [08:16<00:04,  1.45it/s]Python(72199) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(72200) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# 100%|█████████▉| 995/1000 [08:17<00:03,  1.43it/s]Python(72201) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(72202) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# 100%|█████████▉| 996/1000 [08:18<00:02,  1.44it/s]Python(72203) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(72204) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# 100%|█████████▉| 997/1000 [08:19<00:02,  1.44it/s]Python(72205) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(72206) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# 100%|█████████▉| 998/1000 [08:19<00:01,  1.38it/s]Python(72207) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(72208) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# 100%|█████████▉| 999/1000 [08:20<00:00,  1.40it/s]Python(72209) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(72210) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# 100%|██████████| 1000/1000 [08:21<00:00,  2.00it/s]

# %%
from tqdm import tqdm
from sklearn.preprocessing import OneHotEncoder
import warnings

warnings.filterwarnings("ignore", category=FutureWarning)


def get_ohe_data(part_path, plink_train, raw_train, raw_test):
    bim_data = pd.read_csv(f'{plink_train}.bim', sep='\t', header=None, 
                       names=['CHR', 'SNP', 'GEN_DIST', 'BP', 'A1', 'A2'])
    bim_data.set_index('SNP', inplace=True)

    train_ohes = []
    test_ohes = []
    
    for train_part, test_part in tqdm(zip(raw_train, raw_test)):
        columns = []
        for column in train_part.drop(columns=["IID", "PAT", "MAT", "SEX"]).columns[2:]:
            a1 = bim_data.loc[column[:-2], 'A1']
            a2 = bim_data.loc[column[:-2], 'A2']
            df_new = pd.DataFrame()
            df_new[column[:-2]] = train_part[column].apply(lambda x: create_genome(x, a1, a2))
            columns.append(df_new)
        train_letter_part = pd.concat(columns, axis=1)

        columns = []
        for column in test_part.drop(columns=["IID", "PAT", "MAT", "SEX"]).columns[2:]:
            a1 = bim_data.loc[column[:-2], 'A1']
            a2 = bim_data.loc[column[:-2], 'A2']
            df_new = pd.DataFrame()
            df_new[column[:-2]] = test_part[column].apply(lambda x: create_genome(x, a1, a2))
            columns.append(df_new)
        test_letter_part = pd.concat(columns, axis=1)

        enc = OneHotEncoder(handle_unknown='ignore', sparse_output=False)
        train_ohe = enc.fit_transform(train_letter_part)
        columns = enc.get_feature_names_out()
        train_ohe = pd.DataFrame(columns=columns, data=train_ohe)
        test_ohe = enc.transform(test_letter_part)
        test_ohe = pd.DataFrame(columns=columns, data=test_ohe)
        train_ohes.append(train_ohe)
        test_ohes.append(test_ohe)
    train = pd.concat(train_ohes, axis=1)
    test = pd.concat(test_ohes, axis=1)
    y_train = raw_train[0]["PHENOTYPE"]
    y_test = raw_test[0]["PHENOTYPE"]
    return train, y_train, test, y_test

# %%
X_train, y_train, X_val, y_val = get_ohe_data("./parts", "all_train", raw_train, raw_test)
# Out:
# 1000it [56:32,  3.39s/it]

# %%
from sklearn.decomposition import PCA

X_train_parts = []
X_val_parts = []
for i in range((X_train.shape[1] // 200000) + 1):
    pca = PCA(n_components=20)
    X_train_part = pca.fit_transform(X_train.iloc[:, i * 200000:(i + 1) * 200000])
    X_train_parts.append(X_train_part)
    X_val_part = pca.transform(X_val.iloc[:, i * 200000:(i + 1) * 200000])
    X_val_parts.append(X_val_part)
X_train_pca = np.concatenate(X_train_parts, axis=1)
X_val_pca = np.concatenate(X_val_parts, axis=1)

# %%
np.savetxt('all_train_pca_n.csv', X_train_pca, delimiter=',', fmt='%.8f')
np.savetxt('validation_pca_n.csv', X_val_pca, delimiter=',', fmt='%.8f')

# %% [markdown]
# На следующих 3х ячейках код часто падает из-за отказа ядра. Поэтому результирующие csv были получены запуском итераций отдельно с перезапуском ноутбука между ними.

# %%
X_trains = []
y_trains = []
X_vals = []
y_vals = []
for i in range(1, 6):
    print(1)
    raw_train = get_raw_data_parts("./parts", f"train_{i}")
    raw_test = get_raw_data_parts("./parts", f"test_{i}")
    X_train, y_train, X_val, y_val = get_ohe_data("./parts", f"train_{i}", raw_train, raw_test)
    X_trains.append(X_train)
    y_trains.append(y_train)
    X_vals.append(X_val)
    y_vals.append(y_val)

# %%
from sklearn.decomposition import PCA

X_trains_pca = []
X_vals_pca = []
for i in range(0, 5):
    X_train = X_trains[i]
    y_train = y_trains[i]
    X_val = X_vals[i]
    y_val = y_vals[i]
    X_train_parts = []
    X_val_parts = []
    for i in range((X_train.shape[1] // 200000) + 1):
        pca = PCA(n_components=20)
        X_train_part = pca.fit_transform(X_train.iloc[:, i * 200000:(i + 1) * 200000])
        X_train_parts.append(X_train_part)
        X_val_part = pca.transform(X_val.iloc[:, i * 200000:(i + 1) * 200000])
        X_val_parts.append(X_val_part)
    X_train_pca = np.concatenate(X_train_parts, axis=1)
    X_val_pca = np.concatenate(X_val_parts, axis=1)
    X_trains_pca.append(X_train_pca)
    X_vals_pca.append(X_val_pca)

# %%
np.savetxt('train_1_pca_n.csv', X_trains_pca[0], delimiter=',', fmt='%.8f')
np.savetxt('test_1_pca_n.csv', X_vals_pca[0], delimiter=',', fmt='%.8f')
np.savetxt('train_2_pca_n.csv', X_trains_pca[1], delimiter=',', fmt='%.8f')
np.savetxt('test_2_pca_n.csv', X_vals_pca[1], delimiter=',', fmt='%.8f')
np.savetxt('train_3_pca_n.csv', X_trains_pca[2], delimiter=',', fmt='%.8f')
np.savetxt('test_3_pca_n.csv', X_vals_pca[2], delimiter=',', fmt='%.8f')
np.savetxt('train_4_pca_n.csv', X_trains_pca[3], delimiter=',', fmt='%.8f')
np.savetxt('test_4_pca_n.csv', X_vals_pca[3], delimiter=',', fmt='%.8f')
np.savetxt('train_5_pca_n.csv', X_trains_pca[4], delimiter=',', fmt='%.8f')
np.savetxt('test_5_pca_n.csv', X_vals_pca[4], delimiter=',', fmt='%.8f')

# %%
X_train = np.loadtxt(f'./csv/all_train_pca_n.csv', delimiter=',')
y_train = np.array(pd.read_csv(f'all_train.fam', delim_whitespace=True, header=None)[5]) - 1
X_val = np.loadtxt(f'./csv/validation_pca_n.csv', delimiter=',')
y_val = np.array(pd.read_csv(f'validation.fam', delim_whitespace=True, header=None)[5]) - 1

# %%
ss = StandardScaler()
X_train = ss.fit_transform(X_train)
X_val = ss.transform(X_val)

model_gb = LogisticRegression()
model_gb.fit(X_train, y_train)

y_pred_proba = model_gb.predict_proba(X_val)[:, 1]

# Вычисление и вывод ROC-AUC
roc_auc = roc_auc_score(y_val, y_pred_proba)
print(f'ROC-AUC pca only: {roc_auc:.4f}')
# Out:
# ROC-AUC pca only: 0.4924

# %%
ss = StandardScaler()
X_train = ss.fit_transform(X_train)
X_val = ss.transform(X_val)

selector = SelectKBest(f_classif, k=5)
X_train_s = selector.fit_transform(X_train, y_train)
X_val_s = selector.transform(X_val)

model_gb = LogisticRegression()
model_gb.fit(X_train_s, y_train)

y_pred_proba = model_gb.predict_proba(X_val_s)[:, 1]

# Вычисление и вывод ROC-AUC
roc_auc = roc_auc_score(y_val, y_pred_proba)
print(f'ROC-AUC pca only: {roc_auc:.4f}')
# Out:
# ROC-AUC pca only: 0.5226

# %%
X_trains_pca = []
X_vals_pca = []
for i in range(1, 6):
    X_train_pca = np.loadtxt(f'./csv/train_{i}_pca_n.csv', delimiter=',')
    X_val_pca = np.loadtxt(f'./csv/test_{i}_pca_n.csv', delimiter=',')
    X_trains_pca.append(X_train_pca)
    X_vals_pca.append(X_val_pca)
    y_train = np.array(pd.read_csv(f'train_{i}.fam', delim_whitespace=True, header=None)[5])
    y_test = np.array(pd.read_csv(f'test_{i}.fam', delim_whitespace=True, header=None)[5])
    y_trains.append(y_train)
    y_vals.append(y_test)

# %%
rocs = []
for i in range(5):
    X_train_pca = X_trains_pca[i]
    X_val_pca = X_vals_pca[i]
    y_train = y_trains[i] - 1
    y_val = y_vals[i] - 1

    ss = StandardScaler()
    X_train = ss.fit_transform(X_train_pca)
    X_val = ss.transform(X_val_pca)

    model_gb = LogisticRegression()
    model_gb.fit(X_train, y_train)

    y_pred_proba = model_gb.predict_proba(X_val)[:, 1]

    # Вычисление и вывод ROC-AUC
    roc_auc = roc_auc_score(y_val, y_pred_proba)
    rocs.append(roc_auc)
    print(f'ROC-AUC pca only: {roc_auc:.4f}')
print(np.mean(rocs))
# Out:
# ROC-AUC pca only: 0.5052
# ROC-AUC pca only: 0.3859
# ROC-AUC pca only: 0.4945
# ROC-AUC pca only: 0.4394
# ROC-AUC pca only: 0.3952
# 0.44403316777653556

# %%
rocs = []
for i in range(5):
    X_train_pca = X_trains_pca[i]
    X_val_pca = X_vals_pca[i]
    y_train = y_trains[i] - 1
    y_val = y_vals[i] - 1
    
    ss = StandardScaler()
    X_train = ss.fit_transform(X_train_pca)
    X_val = ss.transform(X_val_pca)

    selector = SelectKBest(f_classif, k=5)
    X_train_new = selector.fit_transform(X_train_pca, y_train)
    X_val_new = selector.transform(X_val_pca)

    model_gb = LogisticRegression()
    model_gb.fit(X_train_new, y_train)

    y_pred_proba = model_gb.predict_proba(X_val_new)[:, 1]

    # Вычисление и вывод ROC-AUC
    roc_auc = roc_auc_score(y_val, y_pred_proba)
    rocs.append(roc_auc)
    print(f'ROC-AUC pca only: {roc_auc:.4f}')
print(np.mean(rocs))
# Out:
# ROC-AUC pca only: 0.4538
# ROC-AUC pca only: 0.4337
# ROC-AUC pca only: 0.4830
# ROC-AUC pca only: 0.4865
# ROC-AUC pca only: 0.4668
# 0.46475819370822435
